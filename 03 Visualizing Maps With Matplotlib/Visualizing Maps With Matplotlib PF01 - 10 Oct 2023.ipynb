# %% [markdown]
# # **Setup**

# %%
# !python3 --version

from psutil import *
print('CPU Core Count: ',cpu_count())
print(f'System RAM: {virtual_memory()[0]/1024/1024/1024:.2f} GB')
# Out:
# Python 3.11.4
# CPU Core Count:  8
# System RAM: 8.00 GB

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

import matplotlib.patheffects as PathEffects
from matplotlib.patches import Polygon

# %%
# Seaborn Theme
font_family = "sans"
background_color = "#D4F1F4"
text_color = "#040303"

sns.set_style({
    "axes.facecolor": background_color,
    "figure.facecolor": background_color,
    "font.family": font_family,
    "text.color": text_color,
})

# %%
# https://towardsdatascience.com/matplotlib-tutorial-lets-take-your-country-maps-to-another-level-a6bd1f40fff

# %% [markdown]
# # **Data Import**

# %%
world = gpd.read_file('WB_Boundaries_GeoJSON_highres/WB_countries_Admin0.geojson')
world.loc[world.NAME_EN == "Seychelles", "CONTINENT"] = "Africa"
world.loc[world.NAME_EN == "Equatorial Guinea", "INCOME_GRP"] = "3. Upper middle income"

print(world.shape)
print(world.columns)
# Out:
# (251, 54)
# Index(['FID', 'OBJECTID', 'featurecla', 'LEVEL', 'TYPE', 'FORMAL_EN',
#        'FORMAL_FR', 'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR',
#        'LASTCENSUS', 'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'CONTINENT',
#        'REGION_UN', 'SUBREGION', 'REGION_WB', 'NAME_AR', 'NAME_BN', 'NAME_DE',
#        'NAME_EN', 'NAME_ES', 'NAME_FR', 'NAME_EL', 'NAME_HI', 'NAME_HU',
#        'NAME_ID', 'NAME_IT', 'NAME_JA', 'NAME_KO', 'NAME_NL', 'NAME_PL',
#        'NAME_PT', 'NAME_RU', 'NAME_SV', 'NAME_TR', 'NAME_VI', 'NAME_ZH',
#        'WB_NAME', 'WB_RULES', 'WB_REGION', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# # **Create Africa Data**

# %%
# Create Separate Data For Africa
africa = world[world.CONTINENT == "Africa"].reset_index(drop=True)

# Read Disputed Area Data
disputed_areas = gpd.read_file("WB_Boundaries_GeoJSON_highres/WB_Admin0_disputed_areas.geojson")
disputed_areas = disputed_areas[disputed_areas.CONTINENT == "Africa"]

# %% [markdown]
# # **Define Draw Map Function**

# %%
def draw_map(maps_to_draw,boundry_map_index=0,use_hatch_for_indexes=[],padding={},labels=[],figsize=(40, 40)):   
    assert "color" in maps_to_draw[0].columns, "Missing color column in map dataframe"
    assert "edgecolor" in maps_to_draw[0].columns, "Missing edgecolor column in map dataframe"
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot()
    for map_index, map_to_draw in enumerate(maps_to_draw):
        map_to_draw.plot(
            ax=ax, color=map_to_draw.color, edgecolor=map_to_draw.edgecolor,
            hatch="//" if map_index in use_hatch_for_indexes else "",)
    # Additional functions below this comment
    return ax

# %%
world["color"] = "#f0f0f0"
world["edgecolor"] = "#c0c0c0"

africa["edgecolor"] = "#000000"
africa.loc[africa.INCOME_GRP == "5. Low income", "color"] = "#dadada"
africa.loc[africa.INCOME_GRP == "4. Lower middle income", "color"] = "#89bab2"
africa.loc[africa.INCOME_GRP == "3. Upper middle income", "color"] = "#1B998B"

disputed_areas["color"] = "#FFD6D6"
disputed_areas["edgecolor"] = "#000000"

# %% [markdown]
# # **Create Map**

# %%
ax = draw_map(maps_to_draw=[world, africa, disputed_areas])
plt.axis("off")
plt.show()

# %% [markdown]
# # **Define Map Cropping Function**

# %%
def set_limits(ax, data, pad_left=0, pad_right=0, pad_top=0, pad_bottom=0):
    xmin_ = data.bounds.minx.min()
    ymin_ = data.bounds.miny.min()
    xmax_ = data.bounds.maxx.max()
    ymax_ = data.bounds.maxy.max()
    
    xmin = xmin_ - pad_left * (xmax_ - xmin_)
    xmax = xmax_ + pad_right * (xmax_ - xmin_)
    ymin = ymin_ - pad_bottom * (ymax_ - ymin_)
    ymax = ymax_ + pad_top * (ymax_ - ymin_)
    
    ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))

# %% [markdown]
# # **Define Draw Map Function**

# %%
def draw_map(maps_to_draw,boundry_map_index=0,use_hatch_for_indexes=[],padding={},labels=[],figsize=(40, 40)):   
    assert "color" in maps_to_draw[0].columns, "Missing color column in map dataframe"
    assert "edgecolor" in maps_to_draw[0].columns, "Missing edgecolor column in map dataframe"
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot()
    for map_index, map_to_draw in enumerate(maps_to_draw):
        map_to_draw.plot(
            ax=ax, color=map_to_draw.color, edgecolor=map_to_draw.edgecolor,
            hatch="//" if map_index in use_hatch_for_indexes else "",)
    
    # Additional functions below this comment
    set_limits(ax,maps_to_draw[boundary_map_index], **padding)

    return ax

# %% [markdown]
# # **Create Map 02**

# %%
ax = draw_map(maps_to_draw=[world, africa, disputed_areas], boundry_map_index=1,
            padding={"pad_bottom": -0.08, "pad_top": 0.07, "pad_left": 0.07, "pad_right": 0.05},
            use_hatch_for_indexes=[2])
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06 Data Science & Analytics/Practice Projects/32 Visualizing Maps With Matplotlib/Visualizing Maps With Matplotlib PF01 - 10 Oct 2023.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> ax = draw_map(maps_to_draw=[world, africa, disputed_areas], boundry_map_index=1,
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>             padding={"pad_bottom": -0.08, "pad_top": 0.07, "pad_left": 0.07, "pad_right": 0.05},
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>             use_hatch_for_indexes=[2])
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> plt.axis("off")
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> plt.show()
#
# /Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06 Data Science & Analytics/Practice Projects/32 Visualizing Maps With Matplotlib/Visualizing Maps With Matplotlib PF01 - 10 Oct 2023.ipynb Cell 20 line 1
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a>     map_to_draw.plot(
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a>         ax=ax, color=map_to_draw.color, edgecolor=map_to_draw.edgecolor,
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a>         hatch="//" if map_index in use_hatch_for_indexes else "",)
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a> # Additional functions below this comment
# ---> <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=11'>12</a> set_limits(ax,maps_to_draw[boundary_map_index], **padding)
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X26sZmlsZQ%3D%3D?line=13'>14</a> return ax
#
# NameError: name 'boundary_map_index' is not defined

# %%
# Africa Map without the Adjoining Countries
ax = draw_map(maps_to_draw=[africa, disputed_areas], boundry_map_index=1,
            padding={"pad_bottom": -0.08, "pad_top": 0.07, "pad_left": 0.07, "pad_right": 0.05},
            use_hatch_for_indexes=[2])
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06 Data Science & Analytics/Practice Projects/32 Visualizing Maps With Matplotlib/Visualizing Maps With Matplotlib PF01 - 10 Oct 2023.ipynb Cell 21 line 2
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Africa Map without the Adjoining Countries
# ----> <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> ax = draw_map(maps_to_draw=[africa, disputed_areas], boundry_map_index=1,
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>             padding={"pad_bottom": -0.08, "pad_top": 0.07, "pad_left": 0.07, "pad_right": 0.05},
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a>             use_hatch_for_indexes=[2])
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> plt.axis("off")
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# /Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06 Data Science & Analytics/Practice Projects/32 Visualizing Maps With Matplotlib/Visualizing Maps With Matplotlib PF01 - 10 Oct 2023.ipynb Cell 21 line 1
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=6'>7</a>     map_to_draw.plot(
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=7'>8</a>         ax=ax, color=map_to_draw.color, edgecolor=map_to_draw.edgecolor,
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=8'>9</a>         hatch="//" if map_index in use_hatch_for_indexes else "",)
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=10'>11</a> # Additional functions below this comment
# ---> <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=11'>12</a> set_limits(ax,maps_to_draw[boundary_map_index], **padding)
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X30sZmlsZQ%3D%3D?line=13'>14</a> return ax
#
# NameError: name 'boundary_map_index' is not defined

# %% [markdown]
# # **Define Add_Label Function**

# %%
def add_label(ax, label, fontsize=24, fontweight="bold", va="center", ha="center"):            
    annotation = plt.annotate(
        label["label"], 
        xy=label["xytext"] if "xypin" not in label.keys() else label["xypin"], 
        xytext=None if "xypin" not in label.keys() else label["xytext"], 
        xycoords="data", fontsize=fontsize, va=va, ha=ha,
        linespacing=1.3, color=label["color"], fontweight=fontweight, 
        arrowprops={
            "arrowstyle": "-",
            "linewidth": 2,
        })
    
    annotation.set_path_effects([PathEffects.withStroke(linewidth=6, foreground='w')])

# %% [markdown]
# # **Create Country Names List**

# %%
country_labels = [
    {"label": "Algeria", "color": "#040303", "xytext": (2.0, 27.5)},
    {"label": "Angola", "color": "#040303", "xytext": (17.7, -13.1)},
    {"label": "Benin", "color": "#040303", "xytext": (3.2, 5.4), "xypin": (2.3, 7.6)},
    {"label": "Botswana", "color": "#040303", "xytext": (24.4, -22.3)},
    {"label": "Burkina\nFaso", "color": "#040303", "xytext": (-1.4, 12.6)},
    {"label": "Burundi", "color": "#040303", "xytext": (43.3, -4.9), "xypin": (29.8, -3.6)},
    {"label": "Cameroon", "color": "#040303", "xytext": (12.5, 5.2)},
    {"label": "Cape Verde", "color": "#040303", "xytext": (-23.7, 19), "xypin": (-23.7, 16)},
    {"label": "Central African\nRepublic", "color": "#040303", "xytext": (21.1, 6.5)},
    {"label": "Chad", "color": "#040303", "xytext": (18.5, 16.0)},
    {"label": "Comoros", "color": "#040303", "xytext": (46.8, -9.6), "xypin": (43.3, -11.7)},
    {"label": "Cote\nd'Ivoire", "color": "#040303", "xytext": (-5.5, 8.5)},
    {"label": "Democratic\nRepublic of\nthe Congo", "color": "#040303", "xytext": (23.3, -2.7)},
    {"label": "Djibouti", "color": "#040303", "xytext": (47.0, 13.4), "xypin": (43.0, 12.2)},
    {"label": "Egypt", "color": "#040303", "xytext": (29.2, 26.6)},
    {"label": "Equatorial\nGuinea", "color": "#040303", "xytext": (5.9, -2.5), "xypin": (10.5, 1.6)},
    {"label": "Eritrea", "color": "#040303", "xytext": (43.0, 16.9), "xypin": (38.5, 16.2)},
    {"label": "Lesotho", "color": "#040303", "xytext": (35.0, -31.0), "xypin": (28.4, -29.5)},
    {"label": "Ethiopia", "color": "#040303", "xytext": (39.9, 8.5)},
    {"label": "Gabon", "color": "#040303", "xytext": (11.8, -0.7)},
    {"label": "Ghana", "color": "#040303", "xytext": (-1.3, 6.6)},
    {"label": "Guinea", "color": "#040303", "xytext": (-11.6, 11.0)},
    {"label": "Guinea-\nBissau", "color": "#040303", "xytext": (-20.3, 10.3), "xypin": (-14.5, 12.2)},
    {"label": "Kenya", "color": "#040303", "xytext": (37.9, 0.5)},
    {"label": "Eswantini", "color": "#040303", "xytext": (35.5, -29.3), "xypin": (31.5, -26.8)},
    {"label": "Liberia", "color": "#040303", "xytext": (-10.6, 3.6), "xypin": (-9.6, 6.7)},
    {"label": "Libya", "color": "#040303", "xytext": (17.5, 27.5)},
    {"label": "Madagascar", "color": "#040303", "xytext": (46.7, -19.6)},
    {"label": "Malawi", "color": "#040303", "xytext": (38.9, -21.3), "xypin": (35.0, -15.6)},
    {"label": "Mali", "color": "#040303", "xytext": (-1.9, 17.8)},
    {"label": "Mauritania", "color": "#040303", "xytext": (-11.1, 19.6)},
    {"label": "Morocco", "color": "#040303", "xytext": (-6.9, 31.3)},
    {"label": "Mozambique", "color": "#040303", "xytext": (40.8, -15.2)},
    {"label": "Namibia", "color": "#040303", "xytext": (17.3, -20.7)},
    {"label": "Niger", "color": "#040303", "xytext": (9.8, 17.5)},
    {"label": "Nigera", "color": "#040303", "xytext": (7.8, 9.8)},
    {"label": "Republic of\nthe Congo", "color": "#040303", "xytext": (7.8, -7.2), "xypin": (12.0, -4.1)},
    {"label": "Rwanda", "color": "#040303", "xytext": (43.8, -3.6), "xypin": (30.1, -2.0)},
    {"label": "São Tomé and\nPríncipe", "color": "#040303", "xytext": (-0.9, 0.2), "xypin": (6.8, 0.2)},
    {"label": "Senegal", "color": "#040303", "xytext": (-15.0, 14.7)},
    {"label": "Seychelles", "color": "#040303", "xytext": (55.6, -2), "xypin": (55.6, -4.5)},
    {"label": "Sierra Leone", "color": "#040303", "xytext": (-16.4, 6.3), "xypin": (-12.0, 8.5)},
    {"label": "Somalia", "color": "#040303", "xytext": (45.7, 2.7)},
    {"label": "South\nAfrica", "color": "#040303", "xytext": (22.4, -31.0)},
    {"label": "South\nSudan", "color": "#040303", "xytext": (30.2, 7.0)},
    {"label": "Sudan", "color": "#040303", "xytext": (29.7, 16.0)},
    {"label": "Tanzania", "color": "#040303", "xytext": (35.0, -6.7)},
    {"label": "The\nGambia", "color": "#040303", "xytext": (-20.3, 13.6), "xypin": (-15.4, 13.6)},
    {"label": "Togo", "color": "#040303", "xytext": (1.0, 4.1), "xypin": (1.0, 7.5)},
    {"label": "Tunisia", "color": "#040303", "xytext": (9.3, 38.9), "xypin": (9.3, 35.7)},
    {"label": "Uganda", "color": "#040303", "xytext": (32.6, 0.9)},
    {"label": "Zambia", "color": "#040303", "xytext": (26.1, -14.9)},
    {"label": "Zimbawe", "color": "#040303", "xytext": (29.7, -19.1)},
]

# %% [markdown]
# # **Define Draw Map Function**

# %%
def draw_map(maps_to_draw,boundry_map_index=0,use_hatch_for_indexes=[],padding={},labels=[],figsize=(40, 40)):   
    assert "color" in maps_to_draw[0].columns, "Missing color column in map dataframe"
    assert "edgecolor" in maps_to_draw[0].columns, "Missing edgecolor column in map dataframe"
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot()
    for map_index, map_to_draw in enumerate(maps_to_draw):
        map_to_draw.plot(
            ax=ax, color=map_to_draw.color, edgecolor=map_to_draw.edgecolor,
            hatch="//" if map_index in use_hatch_for_indexes else "",)
    
    # Additional functions below this comment
    set_limits(ax,maps_to_draw[boundary_map_index], **padding)

    # Add Labels
    for label in labels:
        add_label(ax, label)
        
    return ax

# %%
# Without Adjoining Countries
ax = draw_map(maps_to_draw=[africa, disputed_areas], boundry_map_index=1,
    padding={"pad_bottom": -0.08, "pad_top": 0.07, "pad_left": 0.07, "pad_right": 0.05},
    use_hatch_for_indexes=[2],labels=country_labels,figsize=(10,10))
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06 Data Science & Analytics/Practice Projects/32 Visualizing Maps With Matplotlib/Visualizing Maps With Matplotlib PF01 - 10 Oct 2023.ipynb Cell 28 line 2
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> # Without Adjoining Countries
# ----> <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> ax = draw_map(maps_to_draw=[africa, disputed_areas], boundry_map_index=1,
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a>     padding={"pad_bottom": -0.08, "pad_top": 0.07, "pad_left": 0.07, "pad_right": 0.05},
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a>     use_hatch_for_indexes=[2],labels=country_labels,figsize=(10,10))
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> plt.axis("off")
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# /Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06 Data Science & Analytics/Practice Projects/32 Visualizing Maps With Matplotlib/Visualizing Maps With Matplotlib PF01 - 10 Oct 2023.ipynb Cell 28 line 1
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=6'>7</a>     map_to_draw.plot(
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=7'>8</a>         ax=ax, color=map_to_draw.color, edgecolor=map_to_draw.edgecolor,
#       <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a>         hatch="//" if map_index in use_hatch_for_indexes else "",)
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a> # Additional functions below this comment
# ---> <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=11'>12</a> set_limits(ax,maps_to_draw[boundary_map_index], **padding)
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=13'>14</a> # Add Labels
#      <a href='vscode-notebook-cell:/Users/akshayyewle/Library/CloudStorage/OneDrive-Personal/06%20Data%20Science%20%26%20Analytics/Practice%20Projects/32%20Visualizing%20Maps%20With%20Matplotlib/Visualizing%20Maps%20With%20Matplotlib%20PF01%20-%2010%20Oct%202023.ipynb#X41sZmlsZQ%3D%3D?line=14'>15</a> for label in labels:
#
# NameError: name 'boundary_map_index' is not defined
