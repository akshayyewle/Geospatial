# %% [markdown]
# # **Setup**

# %%
import pandas as pd 
import geopandas as gpd

import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import clear_output

# %%
folder_input = 'Input Data'

# %% [markdown]
# # **Data Import**

# %%
municipality =  gpd.read_file(f'{folder_input}/municipality.shp')
municipality_geojson =  gpd.read_file(f'{folder_input}/municipality.geojson')

# %%
# No. Of Municipality Regions
len(municipality_geojson)
# Out:
# 775

# %%
municipality.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PROVINCE  775 non-null    int64
#  1   PR_NAME   775 non-null    object
#  2   DISTRICT  775 non-null    object
#  3   PALIKA    775 non-null    object
#  4   TYPE      775 non-null    object
#  5   geometry  775 non-null    geometry
# dtypes: geometry(1), int64(1), object(4)
# memory usage: 36.5+ KB

# %%
municipality.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# 774    Polygon
# Length: 775, dtype: object

# %% [markdown]
# ## **Metadata**

# %%
# Get CRS
municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
type(municipality)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# # **Map Visualization**

# %%
municipality.plot(figsize=(8,8 ))
# Out:
# <Axes: >

# %%
# Show Only Boundary
municipality.boundary.plot()
# Out:
# <Axes: >

# %%
municipality.plot('PR_NAME',cmap='magma',legend=True)
# Out:
# <Axes: >

# %%
# Set Axis Off
map_01 = municipality.plot('PR_NAME',cmap='magma',legend=False)
map_01.set_axis_off()

# %% [markdown]
# ## **Rupandehi District**

# %%
rupandehi = municipality[municipality['DISTRICT']=='RUPANDEHI']

print('No. Of Municipals: ',len(rupandehi))
print('Data Shape: ',rupandehi.shape)
rupandehi.head()
# Out:
# No. Of Municipals:  17
# Data Shape:  (17, 7)
#      PROVINCE        PR_NAME   DISTRICT     PALIKA                TYPE  \
# 509         5  Province No 5  RUPANDEHI     Butwal  Upamahanagarpalika
# 510         5  Province No 5  RUPANDEHI    Devdaha         Nagarpalika
# 511         5  Province No 5  RUPANDEHI  Gaidahawa          Gaunpalika
# 512         5  Province No 5  RUPANDEHI    Kanchan          Gaunpalika
# 513         5  Province No 5  RUPANDEHI  Kotahimai          Gaunpalika
#
#                                               geometry        Area
# 509  POLYGON ((83.39404 27.74746, 83.39444 27.74707...  101.878829
# 510  POLYGON ((83.50562 27.72572, 83.50622 27.72560...  137.290234
# 511  POLYGON ((83.32845 27.65126, 83.32876 27.65095...   97.071083
# 512  POLYGON ((83.26076 27.69161, 83.26059 27.68940...   58.669750
# 513  POLYGON ((83.33693 27.48945, 83.33803 27.48927...   58.408883

# %%
rupandehi.plot()
# Out:
# <Axes: >

# %%
rupandehi.plot('PALIKA',cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# ## **Palpa District**

# %%
palpa = municipality[municipality['DISTRICT']=='PALPA']

print('No. Of Municipals: ',len(palpa))
print('Data Shape: ',palpa.shape)
palpa.head()
# Out:
# No. Of Municipals:  10
# Data Shape:  (10, 7)
#      PROVINCE        PR_NAME DISTRICT              PALIKA        TYPE  \
# 492         5  Province No 5    PALPA          Bagnaskali  Gaunpalika
# 493         5  Province No 5    PALPA          Mathagadhi  Gaunpalika
# 494         5  Province No 5    PALPA               Nisdi  Gaunpalika
# 495         5  Province No 5    PALPA          Purbakhola  Gaunpalika
# 496         5  Province No 5    PALPA  Rainadevi Chhahara  Gaunpalika
#
#                                               geometry        Area
# 492  POLYGON ((83.57804 27.93438, 83.57730 27.93346...   84.365058
# 493  POLYGON ((83.64819 27.87138, 83.64852 27.87120...  215.983972
# 494  POLYGON ((84.02717 27.85081, 84.02673 27.85023...  194.882576
# 495  POLYGON ((83.73864 27.88954, 83.73903 27.88936...  138.337975
# 496  POLYGON ((83.38043 27.95803, 83.38030 27.95774...  176.373342

# %%
palpa.plot('PALIKA',cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# ## **Combine Regions In A Single Map**

# %%
map_02 = rupandehi.plot(figsize=(6,6))
palpa.plot(ax=map_02)
# Out:
# <Axes: >

# %% [markdown]
# # **Add Area Column**

# %%
print(municipality.shape,'\n')
municipality.head()
# Out:
# (775, 6)
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality['Area'] = municipality['geometry'].to_crs(epsg=32645).area/(10**6)

municipality.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry         Area
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...    88.521700
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...   137.371061
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...   209.626709
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...   441.435863
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...  1851.420797

# %%
municipality.plot('Area',legend=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Working With Geometry**

# %%
import shapely
from shapely.geometry import Point,LineString, Polygon

# %% [markdown]
# ## **Create A Point**

# %%
# Create A Point
Point_01 = Point(1,1)
Point_01

# %% [markdown]
# ## **Create A Line**

# %%
# Create A Line
Line_01 = LineString([(0,0),(5,9),(10,8)])
Line_01

# %% [markdown]
# ## **Create A Polygon**

# %%
# Create A Polygon
Polygon_01 = Line_01.buffer(1)
Polygon_01

# %% [markdown]
# ## **Check Spatial Relationship**
#
# Relationship Types
# * Contains
# * Touches
# * Overlap

# %%
# Check If Point_01 Is Contained Inside Polygon_01
Point_01.within(Polygon_01)
# Out:
# True

# %%
# Check If Polygon_01 Contains Point_01
Polygon_01.contains(Point_01 )
# Out:
# True

# %% [markdown]
# ## **Create Geo Series**

# %%
Geo_Series_01 = gpd.GeoSeries([Point(-10,15),Point(10,2),Point(-5,16)])

print(type(Geo_Series_01))
Geo_Series_01
# Out:
# <class 'geopandas.geoseries.GeoSeries'>
# 0    POINT (-10.00000 15.00000)
# 1      POINT (10.00000 2.00000)
# 2     POINT (-5.00000 16.00000)
# dtype: geometry

# %%
Geo_Series_01.plot(marker='*',color='red',markersize=100,figsize=(4,4))
# Out:
# <Axes: >

# %% [markdown]
# # **Conditional Plotting**
#
# * Plot All Municipalities With Area > 50 Sq. Km

# %%
municipality[municipality['Area']>100].plot('PALIKA',legend=False)
# Out:
# <Axes: >

# %% [markdown]
# # **Folium Dynamic Maps**

# %%
# !pip install folium
# !pip install mapclassify
clear_output()

# %%
import mapclassify
import folium
import matplotlib

# %% [markdown]
# ## **Rupandehi District Map**

# %%
rupandehi.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5e6a95f7d394b07adbdb71dfc3c82f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5e6a95f7d394b07adbdb71dfc3c82f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5e6a95f7d394b07adbdb71dfc3c82f1 = L.map(
#                 &quot;map_f5e6a95f7d394b07adbdb71dfc3c82f1&quot;,
#                 {
#                     center: [27.54897883206604, 83.42109070368656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f5e6a95f7d394b07adbdb71dfc3c82f1);
#
#
#
#
#
#             var tile_layer_3f1e34b317f091d09ec3f9acaf974ec6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f5e6a95f7d394b07adbdb71dfc3c82f1);
#
#
#             map_f5e6a95f7d394b07adbdb71dfc3c82f1.fitBounds(
#                 [[27.32996283160611, 83.20626251587083], [27.76799483252597, 83.63591889150229]],
#                 {}
#             );
#
#
#         function geo_json_26350ea4acb8a727eee71bf99ecef1c2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_26350ea4acb8a727eee71bf99ecef1c2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_26350ea4acb8a727eee71bf99ecef1c2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_26350ea4acb8a727eee71bf99ecef1c2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_26350ea4acb8a727eee71bf99ecef1c2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_26350ea4acb8a727eee71bf99ecef1c2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_26350ea4acb8a727eee71bf99ecef1c2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_26350ea4acb8a727eee71bf99ecef1c2 = L.geoJson(null, {
#                 onEachFeature: geo_json_26350ea4acb8a727eee71bf99ecef1c2_onEachFeature,
#
#                 style: geo_json_26350ea4acb8a727eee71bf99ecef1c2_styler,
#                 pointToLayer: geo_json_26350ea4acb8a727eee71bf99ecef1c2_pointToLayer
#         });
#
#         function geo_json_26350ea4acb8a727eee71bf99ecef1c2_add (data) {
#             geo_json_26350ea4acb8a727eee71bf99ecef1c2
#                 .addData(data)
#                 .addTo(map_f5e6a95f7d394b07adbdb71dfc3c82f1);
#         }
#             geo_json_26350ea4acb8a727eee71bf99ecef1c2_add({&quot;bbox&quot;: [83.20626251587083, 27.32996283160611, 83.63591889150229, 27.76799483252597], &quot;features&quot;: [{&quot;bbox&quot;: [83.36342326581052, 27.615400769635244, 83.50622426613677, 27.74867389543948], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[83.3940447037059, 27.747463083080333], [83.39444476694712, 27.74707227079415], [83.3949966415754, 27.74662789432108], [83.3953028284431, 27.746464519492918], [83.39573595476725, 27.74634233317073], [83.39591157838333, 27.746232519743955], [83.39643320479775, 27.746036207601946], [83.39652145439487, 27.745962145737735], [83.39681245408622, 27.745624958432643], [83.39699445

# %%
rupandehi.explore(column='PALIKA')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eac8c6617a0bca4c4c14fc7f371229c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend PALIKA&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;PALIKA&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Butwal&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#aec7e8&#x27;&gt;&lt;/span&gt;Devdaha&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;Gaidahawa&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffbb78&#x27;&gt;&lt;/span&gt;Kanchan&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;Kotahimai&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;Lumbini Sanskritik&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff9896&#x27;&gt;&lt;/span&gt;Lumbini Sanskritik Development Area&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9467bd&#x27;&gt;&lt;/span&gt;Marchawari&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;Mayadevi&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#c49c94&#x27;&gt;&lt;/span&gt;Omsatiya&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;Rohini&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#f7b6d2&#x27;&gt;&lt;/span&gt;Sainamaina&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#c7c7c7&#x27;&gt;&lt;/span&gt;Sammarimai&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;Siddharthanagar&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#dbdb8d&#x27;&gt;&lt;/span&gt;Siyari&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;Sudhdhodhan&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Tillotama&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eac8c6617a0bca4c4c14fc7f371229c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eac8c6617a0bca4c4c14fc7f371229c4 = L.map(
#                 &quot;map_eac8c6617a0bca4c4c14fc7f371229c4&quot;,
#                 {
#                     center: [27.54897883206604, 83.42109070368656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_eac8c6617a0bca4c4c14fc7f371229c4);
#
#
#
#
#
#             var tile_layer_f5cf893d169f2e73a58e84d6048e3cb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&q
