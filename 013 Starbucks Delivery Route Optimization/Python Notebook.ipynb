# %% [markdown]
# # **Setup**
#
# * https://towardsdatascience.com/modern-route-optimization-with-python-fea87d34288b
# * https://www.kaggle.com/datasets/starbucks/store-locations

# %%
from IPython.display import clear_output

# !python -m pip install folium
clear_output()
# !python -m pip install osmnx
clear_output()

# %%
import os 
from warnings import filterwarnings
filterwarnings('ignore')

import pandas as pd 
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import plotly.express as px

# For Geospatial Visualization
import folium 
from folium import plugins

# For Routing 
import osmnx as ox
import ortools as ot

# %%
Folder_Input = 'Input Data'

if not os.path.exists(Folder_Input):
    os.mkdir(Folder_Input)

# %% [markdown]
# # **Data Import**

# %% [markdown]
# ## **Data Download**

# %%
os.chdir(Folder_Input)

# !kaggle datasets download -d starbucks/store-locations
os.chdir('..')
# Out:
# Downloading store-locations.zip to c:\Users\aksha\OneDrive\06 Data Science & Analytics\Github\Geospatial\013 Starbucks Delivery Route Optimization\Input Data
#   0%|          | 0.00/1.10M [00:00<?, ?B/s]
#  91%|█████████ | 1.00M/1.10M [00:00<00:00, 2.04MB/s]
# 100%|██████████| 1.10M/1.10M [00:00<00:00, 2.22MB/s]

# %% [markdown]
# ## **Extract Zip File**

# %%
def Extract_Zip(Zip_Filepath, Destination_Path, Delete_Zip):
    from zipfile import ZipFile
    with ZipFile(Zip_Filepath, 'r') as zip:
        zip.extractall(Destination_Path)
        if Delete_Zip:
            os.remove(Zip_Filepath)

# %%
Extract_Zip(Zip_Filepath=f'{Folder_Input}/store-locations.zip',
            Destination_Path=f'{Folder_Input}',Delete_Zip=False)

# %%
os.remove(f'{Folder_Input}/store-locations.zip')

# %%
df = pd.read_csv(f'{Folder_Input}/directory.csv')

print(df.shape)
print(df.columns)
df.head()
# Out:
# (25600, 13)
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Postcode',
#        'Phone Number', 'Timezone', 'Longitude', 'Latitude'],
#       dtype='object')
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %% [markdown]
# ## **Data Review**

# %%
df.isna().sum()
# Out:
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25600 entries, 0 to 25599
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           25600 non-null  object
#  1   Store Number    25600 non-null  object
#  2   Store Name      25600 non-null  object
#  3   Ownership Type  25600 non-null  object
#  4   Street Address  25598 non-null  object
#  5   City            25585 non-null  object
#  6   State/Province  25600 non-null  object
#  7   Country         25600 non-null  object
#  8   Postcode        24078 non-null  object
#  9   Phone Number    18739 non-null  object
#  10  Timezone        25600 non-null  object
#  11  Longitude       25599 non-null  float64
#  12  Latitude        25599 non-null  float64
# dtypes: float64(2), object(11)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#           Longitude      Latitude
# count  25599.000000  25599.000000
# mean     -27.872234     34.793016
# std       96.844046     13.342332
# min     -159.460000    -46.410000
# 25%     -104.665000     31.240000
# 50%      -79.350000     36.750000
# 75%      100.630000     41.570000
# max      176.920000     64.850000

# %% [markdown]
# # **Data Cleaning**

# %%
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
# Remove Postcode & Phone Number Column
df.drop(['Postcode', 'Phone Number','Timezone'], axis=1, inplace=True)

# %%
print(df.shape)
df.head()
# Out:
# (25600, 10)
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#    Longitude  Latitude
# 0       1.53     42.51
# 1      55.47     25.42
# 2      55.47     25.39
# 3      54.38     24.48
# 4      54.54     24.51

# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# ## **Brand Count**

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Starbucks                25249
# Teavana                    348
# Evolution Fresh              2
# Coffee House Holdings        1
# Name: count, dtype: int64

# %% [markdown]
# ## **Ownership Count**

# %%
df['Ownership Type'].value_counts()
# Out:
# Ownership Type
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: count, dtype: int64

# %% [markdown]
# ## **Country Count**

# %%
# Identify The Country With The Highest Number Of Stores
df['Country'].value_counts().head(5)
# Out:
# Country
# US    13608
# CN     2734
# CA     1468
# JP     1237
# KR      993
# Name: count, dtype: int64

# %% [markdown]
# ## **US City Count**

# %%
# Identify US City With Highest Number Of Stores 
df[df['Country']=='US']['City'].value_counts().head(5)
# Out:
# City
# New York     232
# Chicago      180
# Seattle      156
# Las Vegas    156
# Houston      154
# Name: count, dtype: int64

# %% [markdown]
# ## **City With Most Stores**

# %%
df.columns
# Out:
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#    Longitude  Latitude
# 0       1.53     42.51
# 1      55.47     25.42
# 2      55.47     25.39
# 3      54.38     24.48
# 4      54.54     24.51

# %%
df.groupby(by='City')['Store Number'].agg('count').sort_values(ascending=False).head(5)
# Out:
# City
# 上海市         542
# Seoul       243
# 北京市         234
# New York    232
# London      216
# Name: Store Number, dtype: int64

# %%
df[df['City']=='上海市']
# Out:
#           Brand  Store Number Store Name Ownership Type  \
# 2518  Starbucks  24754-238132    汇暻生活广场店  Joint Venture
# 2519  Starbucks  28083-249527      嘉杰广场店  Joint Venture
# 2520  Starbucks  25485-226668       宝乐汇店  Joint Venture
# 2521  Starbucks  27243-246386       中港汇店  Joint Venture
# 2522  Starbucks  24722-238648   松江新理想广场店  Joint Venture
# ...         ...           ...        ...            ...
# 3055  Starbucks  23329-229146      汇商大厦店  Joint Venture
# 3056  Starbucks  31776-114987       金丰路店  Joint Venture
# 3057  Starbucks  15191-153628     浦东嘉里城店  Joint Venture
# 3058  Starbucks  32235-124151      中惠广场店  Joint Venture
# 3059  Starbucks   1396-140870      上海书城店  Joint Venture
#
#                                    Street Address City State/Province Country  \
# 2518               黄浦区, 汇暻生活广场, 四川北路1689号110、202室  上海市             31      CN
# 2519                      虹口区, 牡丹江路1569号F1层F127铺位  上海市             31      CN
# 2520                             上海市, 长寿路828，846号  上海市             31      CN
# 2521                    普陀区, 中港汇大厦, 荣乐西路790号1F-14  上海市             31      CN
# 2522  松江区, 新理想广场, 国际机场交通中心地铁2号线西侧廊道靠中步行道段A标段01号商铺  上海市             31      CN
# ...                                           ...  ...            ...     ...
# 3055                                浦东新区, 金丰路447号  上海市             31      CN
# 3056                           闵行区, 金丰路, 花木路1378号  上海市             31      CN
# 3057        浦东新区, 浦东嘉里城商场一层L110单元, 新金桥路1088号B100室  上海市             31      CN
# 3058                        浦东新区, 中惠广场, 福州路465号2楼  上海市             31      CN
# 3059                 黄浦区, 东侧商铺, 港隆时代广场一号楼102-105室  上海市             31      CN
#
#       Longitude  Latitude
# 2518     121.48     31.20
# 2519     121.48     31.26
# 2520     121.49     31.40
# 2521     121.43     31.24
# 2522     121.20     31.02
# ...         ...       ...
# 3055     121.55     31.22
# 3056     121.28     31.20
# 3057     121.56     31.21
# 3058     121.61     31.25
# 3059     121.48     31.23
#
# [542 rows x 10 columns]

# %% [markdown]
# # **City Data**

# %% [markdown]
# ## **Filter City Data**

# %%
# Select City Name
City_Name = 'New York'

# %%
City = df[df['City']==City_Name]

print(City.shape)
print(City.columns)
City.head()
# Out:
# (232, 10)
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Longitude',
#        'Latitude'],
#       dtype='object')
#            Brand  Store Number         Store Name Ownership Type  \
# 21129  Starbucks    818-227125      80th & Second  Company Owned
# 21130  Starbucks  14318-119964    Nassau & Fulton  Company Owned
# 21131  Starbucks    7670-36979         49th & 8th  Company Owned
# 21132  Starbucks    7626-33939  Spring and Varick  Company Owned
# 21133  Starbucks    7699-45959    95th & Broadway  Company Owned
#
#                               Street Address      City State/Province Country  \
# 21129                       245 East 80th St  New York             NY      US
# 21130                      130 Fulton Street  New York             NY      US
# 21131                 825 Eighth Avenue, W-9  New York             NY      US
# 21132  150 Varick Street, The Lyric Building  New York             NY      US
# 21133                          2521 Broadway  New York             NY      US
#
#        Longitude  Latitude
# 21129     -73.95     40.77
# 21130     -74.01     40.71
# 21131     -73.99     40.76
# 21132     -74.01     40.73
# 21133     -73.97     40.79

# %%
City.drop(columns=['Brand','Ownership Type','Street Address','State/Province'],inplace=True)
City.rename(columns={'Store Number':'StoreID'},inplace=True)
City.reset_index(inplace=True,drop=True)

print(City.shape)
print(City.columns)
City.head()
# Out:
# (232, 6)
# Index(['StoreID', 'Store Name', 'City', 'Country', 'Longitude', 'Latitude'], dtype='object')
#         StoreID         Store Name      City Country  Longitude  Latitude
# 0    818-227125      80th & Second  New York      US     -73.95     40.77
# 1  14318-119964    Nassau & Fulton  New York      US     -74.01     40.71
# 2    7670-36979         49th & 8th  New York      US     -73.99     40.76
# 3    7626-33939  Spring and Varick  New York      US     -74.01     40.73
# 4    7699-45959    95th & Broadway  New York      US     -73.97     40.79

# %% [markdown]
# ## **Visualize Store Locations**

# %%
City['Longitude'].mean()
# Out:
# -73.98275862068965

# %%
City['Latitude'].mean()
# Out:
# 40.75327586206896

# %%
Map01 = folium.Map(location=(City['Latitude'].mean(),City['Longitude'].mean()),zoom_start=12)

for i in range(City.shape[0]):
    folium.CircleMarker(location=(City['Latitude'][i],City['Longitude'][i]),radius=5,color='blue',fill=True).add_to(Map01)

Map01
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_105ea834ef796fce738f7db7d90a2670 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_105ea834ef796fce738f7db7d90a2670&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_105ea834ef796fce738f7db7d90a2670 = L.map(
#                 &quot;map_105ea834ef796fce738f7db7d90a2670&quot;,
#                 {
#                     center: [40.75327586206896, -73.98275862068965],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fc3772791da2ae65c4f170969358f27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7fc3772791da2ae65c4f170969358f27.addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_183c784fd6d27452da8b63095a2eb2db = L.circleMarker(
#                 [40.77, -73.95],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_f8386a3adb783cb44ec2532d1c9e146c = L.circleMarker(
#                 [40.71, -74.01],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_ea49204069d31490abaeeedb65ef06a8 = L.circleMarker(
#                 [40.76, -73.99],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_2594e5163aa7eb2172d91a516e5b9323 = L.circleMarker(
#                 [40.73, -74.01],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_fe30d471acc61f7494ce507f2d0bc9b3 = L.circleMarker(
#                 [40.79, -73.97],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_7162d28ea157ba2016c2edf31da683ed = L.circleMarker(
#                 [40.75, -73.99],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_105ea834ef796fce738f7db7d90a2670);
#
#
#             var circle_marker_fb39b0112903cc0fe4db544ce8bf4ded = L.circleMarker(
#                 [40.78, -73.95],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue
